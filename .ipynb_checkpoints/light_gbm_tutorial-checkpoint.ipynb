# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("./train_data.csv")
test = pd.read_csv("./test_data.csv")

print(train.shape, test.shape)
train.head()
# Out:
# (19720, 17) (29582, 16)
#    id     video_id                                       title  \
# 0   1  GDtyztIThRQ  [12] BGM Inazuma Eleven 3 - ~ライオコツト ダンジョン~
# 1   2  m4H9s3GtTlQ         ねごと - メルシールー [Official Music Video]
# 2   3  z19zYZuLuEU                      VF3tb 闇よだれvsちび太 (SEGA)
# 3   4  pmcIOsL7s98                        free frosty weekend!
# 4   5  ZuQgsTcuM-4                               トップ・オブ・ザ・ワールド
#
#                 publishedAt                 channelId          channelTitle  \
# 0  2011-01-09T05:50:33.000Z  UCQaNYC3dNvH8FqrEyK7hTJw           DjangoShiny
# 1  2012-07-23T03:00:09.000Z  UChMWDi-HBm5aS3jyRSaAWUA  ねごと Official Channel
# 2  2007-07-26T13:54:09.000Z  UCBdcyoZSt5HBLd_n6we-xIg               siropai
# 3  2005-05-15T02:38:43.000Z  UC7K5am1UAQEsCRhzXpi9i1g          Jones4Carrie
# 4  2007-09-09T09:52:47.000Z  UCTW1um4R-QWa8iIfITGvlZQ      Tatsuya Maruyama
#
#    categoryId collection_date  \
# 0          20        20.01.02
# 1          10        20.08.02
# 2          24        20.14.01
# 3          22        19.22.12
# 4          10        20.08.01
#
#                                                 tags  likes  dislikes  \
# 0  Inazuma|Eleven|Super|Once|bgm|ost|イナズマイレブン|Kyo...    114         0
# 1  ねごと|ネゴト|メルシールー|Re:myend|リマインド|Lightdentity|ライデ...   2885        50
# 2  VF3|VF4|VF5|ちび太|闇よだれ|chibita|virtuafighter|seg...    133        17
# 3                                             frosty    287        51
# 4  ギター|guitar|南澤大介|トップオブザワールド|トップ|オブ|ワールド|カーペンターズ...    178         6
#
#    comment_count                                  thumbnail_link  \
# 0              7  https://i.ytimg.com/vi/GDtyztIThRQ/default.jpg
# 1            111  https://i.ytimg.com/vi/m4H9s3GtTlQ/default.jpg
# 2             14  https://i.ytimg.com/vi/z19zYZuLuEU/default.jpg
# 3            173  https://i.ytimg.com/vi/pmcIOsL7s98/default.jpg
# 4             17  https://i.ytimg.com/vi/ZuQgsTcuM-4/default.jpg
#
#    comments_disabled  ratings_disabled  \
# 0              False             False
# 1              False             False
# 2              False             False
# 3              False             False
# 4              False             False
#
#                                          description       y
# 0  ~ライオコツト ダンジョン~Inazuma Eleven 3 BGM Complete (R...   29229
# 1  http://www.negoto.com/全員平成生まれ、蒼山幸子（Vo＆Key)、沙田瑞...  730280
# 2      Beat-tribe cup finalhttp://ameblo.jp/siropai/   80667
# 3                     I look so bad  but look at me!   34826
# 4  ソロギターのしらべより「トップオブザワールド」です。クラシックギターで弾いてます。Offic...  172727

# %%
# trainとtestをくっつけることで前処理を楽にする（同じ動作を繰り返す必要がなくなる）
target = train["y"]
del train["y"]
data = pd.concat([train, test])
print(data.shape)  # 19720 + 29582 = 49302
data.head()
# Out:
# (49302, 16)
#    id     video_id                                       title  \
# 0   1  GDtyztIThRQ  [12] BGM Inazuma Eleven 3 - ~ライオコツト ダンジョン~
# 1   2  m4H9s3GtTlQ         ねごと - メルシールー [Official Music Video]
# 2   3  z19zYZuLuEU                      VF3tb 闇よだれvsちび太 (SEGA)
# 3   4  pmcIOsL7s98                        free frosty weekend!
# 4   5  ZuQgsTcuM-4                               トップ・オブ・ザ・ワールド
#
#                 publishedAt                 channelId          channelTitle  \
# 0  2011-01-09T05:50:33.000Z  UCQaNYC3dNvH8FqrEyK7hTJw           DjangoShiny
# 1  2012-07-23T03:00:09.000Z  UChMWDi-HBm5aS3jyRSaAWUA  ねごと Official Channel
# 2  2007-07-26T13:54:09.000Z  UCBdcyoZSt5HBLd_n6we-xIg               siropai
# 3  2005-05-15T02:38:43.000Z  UC7K5am1UAQEsCRhzXpi9i1g          Jones4Carrie
# 4  2007-09-09T09:52:47.000Z  UCTW1um4R-QWa8iIfITGvlZQ      Tatsuya Maruyama
#
#    categoryId collection_date  \
# 0          20        20.01.02
# 1          10        20.08.02
# 2          24        20.14.01
# 3          22        19.22.12
# 4          10        20.08.01
#
#                                                 tags  likes  dislikes  \
# 0  Inazuma|Eleven|Super|Once|bgm|ost|イナズマイレブン|Kyo...    114         0
# 1  ねごと|ネゴト|メルシールー|Re:myend|リマインド|Lightdentity|ライデ...   2885        50
# 2  VF3|VF4|VF5|ちび太|闇よだれ|chibita|virtuafighter|seg...    133        17
# 3                                             frosty    287        51
# 4  ギター|guitar|南澤大介|トップオブザワールド|トップ|オブ|ワールド|カーペンターズ...    178         6
#
#    comment_count                                  thumbnail_link  \
# 0              7  https://i.ytimg.com/vi/GDtyztIThRQ/default.jpg
# 1            111  https://i.ytimg.com/vi/m4H9s3GtTlQ/default.jpg
# 2             14  https://i.ytimg.com/vi/z19zYZuLuEU/default.jpg
# 3            173  https://i.ytimg.com/vi/pmcIOsL7s98/default.jpg
# 4             17  https://i.ytimg.com/vi/ZuQgsTcuM-4/default.jpg
#
#    comments_disabled  ratings_disabled  \
# 0              False             False
# 1              False             False
# 2              False             False
# 3              False             False
# 4              False             False
#
#                                          description
# 0  ~ライオコツト ダンジョン~Inazuma Eleven 3 BGM Complete (R...
# 1  http://www.negoto.com/全員平成生まれ、蒼山幸子（Vo＆Key)、沙田瑞...
# 2      Beat-tribe cup finalhttp://ameblo.jp/siropai/
# 3                     I look so bad  but look at me!
# 4  ソロギターのしらべより「トップオブザワールド」です。クラシックギターで弾いてます。Offic...

# %%
df["publishedAt"] = pd.to_datetime(df["publishedAt"])
df["publishedAt_year"] = df["publishedAt"].apply(lambda x: x.year)
df["publishedAt_month"] = df["publishedAt"].apply(lambda x: x.month)
df["publishedAt_day"] = df["publishedAt"].apply(lambda x: x.day)
df["length_tags"] = df["tags"].astype(str).apply(lambda x: len(x.split("|")))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-57a1052e2900> in <module>
#       1 data["publishedAt"] = pd.to_datetime(data["publishedAt"])
# ----> 2 df["publishedAt_year"] = df["publishedAt"].apply(lambda x: x.year)
#       3 df["publishedAt_month"] = df["publishedAt"].apply(lambda x: x.month)
#       4 df["publishedAt_day"] = df["publishedAt"].apply(lambda x: x.day)
#       5 data["length_tags"] = data["tags"].astype(str).apply(lambda x: len(x.split("|")))
#
# NameError: name 'df' is not defined

# %%
data.head()
# Out:
#    id     video_id                                       title  \
# 0   1  GDtyztIThRQ  [12] BGM Inazuma Eleven 3 - ~ライオコツト ダンジョン~
# 1   2  m4H9s3GtTlQ         ねごと - メルシールー [Official Music Video]
# 2   3  z19zYZuLuEU                      VF3tb 闇よだれvsちび太 (SEGA)
# 3   4  pmcIOsL7s98                        free frosty weekend!
# 4   5  ZuQgsTcuM-4                               トップ・オブ・ザ・ワールド
#
#                 publishedAt                 channelId          channelTitle  \
# 0 2011-01-09 05:50:33+00:00  UCQaNYC3dNvH8FqrEyK7hTJw           DjangoShiny
# 1 2012-07-23 03:00:09+00:00  UChMWDi-HBm5aS3jyRSaAWUA  ねごと Official Channel
# 2 2007-07-26 13:54:09+00:00  UCBdcyoZSt5HBLd_n6we-xIg               siropai
# 3 2005-05-15 02:38:43+00:00  UC7K5am1UAQEsCRhzXpi9i1g          Jones4Carrie
# 4 2007-09-09 09:52:47+00:00  UCTW1um4R-QWa8iIfITGvlZQ      Tatsuya Maruyama
#
#    categoryId collection_date  \
# 0          20        20.01.02
# 1          10        20.08.02
# 2          24        20.14.01
# 3          22        19.22.12
# 4          10        20.08.01
#
#                                                 tags  likes  ...  \
# 0  Inazuma|Eleven|Super|Once|bgm|ost|イナズマイレブン|Kyo...    114  ...
# 1  ねごと|ネゴト|メルシールー|Re:myend|リマインド|Lightdentity|ライデ...   2885  ...
# 2  VF3|VF4|VF5|ちび太|闇よだれ|chibita|virtuafighter|seg...    133  ...
# 3                                             frosty    287  ...
# 4  ギター|guitar|南澤大介|トップオブザワールド|トップ|オブ|ワールド|カーペンターズ...    178  ...
#
#                                    thumbnail_link  comments_disabled  \
# 0  https://i.ytimg.com/vi/GDtyztIThRQ/default.jpg              False
# 1  https://i.ytimg.com/vi/m4H9s3GtTlQ/default.jpg              False
# 2  https://i.ytimg.com/vi/z19zYZuLuEU/default.jpg              False
# 3  https://i.ytimg.com/vi/pmcIOsL7s98/default.jpg              False
# 4  https://i.ytimg.com/vi/ZuQgsTcuM-4/default.jpg              False
#
#   ratings_disabled                                        description  year  \
# 0            False  ~ライオコツト ダンジョン~Inazuma Eleven 3 BGM Complete (R...  2011
# 1            False  http://www.negoto.com/全員平成生まれ、蒼山幸子（Vo＆Key)、沙田瑞...  2012
# 2            False      Beat-tribe cup finalhttp://ameblo.jp/siropai/  2007
# 3            False                     I look so bad  but look at me!  2005
# 4            False  ソロギターのしらべより「トップオブザワールド」です。クラシックギターで弾いてます。Offic...  2007
#
#   month  day  hour  minute  length_tags
# 0     1    9     5      50           48
# 1     7   23     3       0           19
# 2     7   26    13      54            9
# 3     5   15     2      38            1
# 4     9    9     9      52           12
#
# [5 rows x 22 columns]

# %%
data = data.drop(["channelId",
                  "video_id",
                  "publishedAt", 
                  "thumbnail_link", 
                  "channelTitle",
                  "collection_date",
                  "id",
                  "tags",
                  "description",
                  "title"], axis=1)

# %%
data.head()
# Out:
#    categoryId  likes  dislikes  comment_count  comments_disabled  \
# 0          20    114         0              7              False
# 1          10   2885        50            111              False
# 2          24    133        17             14              False
# 3          22    287        51            173              False
# 4          10    178         6             17              False
#
#    ratings_disabled  year  month  day  hour  minute  length_tags
# 0             False  2011      1    9     5      50           48
# 1             False  2012      7   23     3       0           19
# 2             False  2007      7   26    13      54            9
# 3             False  2005      5   15     2      38            1
# 4             False  2007      9    9     9      52           12

# %%
import gc
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_log_error
import lightgbm as lgb

# %%
train = data.iloc[:len(target), :]
test = data.iloc[len(target):, :]

train.shape, test.shape
# Out:
# ((19720, 12), (29582, 12))

# %%
# Kfold
cv = KFold(n_splits=5, shuffle=True, random_state=2020)
# RMSLE用
score = 0
# testデータの予測用
pred = np.zeros(test.shape[0])

# %%
target = np.log(target)

# %%
target.shape
# Out:
# (19720,)

# %%
params = {
    'boosting_type': 'gbdt',
    'metric': 'rmse',
    'objective': 'regression',
    'seed': 20,
    'learning_rate': 0.01,
    "n_jobs": -1,
    "verbose": -1
}

# %%
for tr_idx, val_idx in cv.split(train):
    x_train, x_val = train.iloc[tr_idx], train.iloc[val_idx]
    y_train, y_val = target[tr_idx], target[val_idx]
    
    # Datasetに入れて学習させる
    train_set = lgb.Dataset(x_train, y_train)
    val_set = lgb.Dataset(x_val, y_val, reference=train_set)
        
    # Training
    model = lgb.train(params, train_set, num_boost_round=8000, early_stopping_rounds=100,
                      valid_sets=[train_set, val_set], verbose_eval=500)
    
    # 予測したらexpで元に戻す
    test_pred = np.exp(model.predict(test))
    # 0より小さな値があるとエラーになるので補正
    test_pred = np.where(test_pred < 0, 0, test_pred)
    pred += test_pred / 5  #  5fold回すので

    oof = np.exp(model.predict(x_val))
    oof = np.where(oof < 0, 0, oof)
    rmsle = np.sqrt(mean_squared_log_error(np.exp(y_val), oof))
    print(f"RMSLE : {rmsle}")
    score += model.best_score["valid_1"]["rmse"] / 5
# Out:
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 0.791144	valid_1's rmse: 0.876442
# Early stopping, best iteration is:
# [804]	training's rmse: 0.748023	valid_1's rmse: 0.869617
# RMSLE : 0.8685395111105162
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 0.793276	valid_1's rmse: 0.866496
# [1000]	training's rmse: 0.728116	valid_1's rmse: 0.854046
# [1500]	training's rmse: 0.685309	valid_1's rmse: 0.851721
# Early stopping, best iteration is:
# [1532]	training's rmse: 0.682531	valid_1's rmse: 0.851597
# RMSLE : 0.8513091319085546
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 0.79403	valid_1's rmse: 0.872361
# [1000]	training's rmse: 0.733515	valid_1's rmse: 0.858896
# [1500]	training's rmse: 0.685541	valid_1's rmse: 0.852299
# [2000]	training's rmse: 0.650575	valid_1's rmse: 0.849164
# [2500]	training's rmse: 0.618365	valid_1's rmse: 0.846067
# [3000]	training's rmse: 0.590655	valid_1's rmse: 0.843633
# Early stopping, best iteration is:
# [3310]	training's rmse: 0.575108	valid_1's rmse: 0.842526
# RMSLE : 0.841595659741775
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 0.795366	valid_1's rmse: 0.872508
# [1000]	training's rmse: 0.730971	valid_1's rmse: 0.862905
# Early stopping, best iteration is:
# [1303]	training's rmse: 0.701976	valid_1's rmse: 0.860068
# RMSLE : 0.8594421228082088
# Training until validation scores don't improve for 100 rounds
# [500]	training's rmse: 0.7969	valid_1's rmse: 0.856636
# [1000]	training's rmse: 0.7333	valid_1's rmse: 0.842781
# [1500]	training's rmse: 0.688047	valid_1's rmse: 0.838777
# Early stopping, best iteration is:
# [1738]	training's rmse: 0.670395	valid_1's rmse: 0.837901
# RMSLE : 0.8375880914257386

# %%
lgb.plot_importance(model, importance_type="gain", max_num_features=20)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
print(f"Mean RMSLE SCORE :{score}")
# Out:
# Mean RMSLE SCORE :0.8523416178635439

# %%
submit_df = pd.DataFrame({"y": pred})
submit_df.index.name = "id"
submit_df.to_csv("submit.csv")
